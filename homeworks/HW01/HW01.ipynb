# %%
import numpy as np

# %%
# создание массива из списка
a = np.array([1, 5, 9, 13])
a
# Out:
# array([ 1,  5,  9, 13])

# %%
# создание массива полностью из 0, из 1 и из интервала с шагом
zeros = np.zeros(7)
ones = np.ones(5)
ar = np.arange(0, 15, 3)

zeros, ones, ar
# Out:
# (array([0., 0., 0., 0., 0., 0., 0.]),
#  array([1., 1., 1., 1., 1.]),
#  array([ 0,  3,  6,  9, 12]))

# %%
# создание двумерного массива и вывод его размера и типа данных
matrix_1 = np.array([[1, 2], [3, 4], [5, 6]])
matrix_1.shape, matrix_1.dtype
# Out:
# ((3, 2), dtype('int32'))

# %%
# получение конкретного элемента массива
matrix_1[1, 1]
# Out:
# 4

# %%
# срез массива
ar[1:4]
# Out:
# array([3, 6, 9])

# %%
# поэлементное сложение и умножение массивов
matrix_2 = np.array([[6, 5], [4, 3], [2, 1]])
matrix_1 + matrix_2, matrix_1 * matrix_2
# Out:
# (array([[7, 7],
#         [7, 7],
#         [7, 7]]),
#  array([[ 6, 10],
#         [12, 12],
#         [10,  6]]))

# %%
# среднеквадратичное отклонение
np.std(matrix_1)
# Out:
# 1.707825127659933
